# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !head -5 titanic_dropna.csv
# Out:
# PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 1,0,3,"Braund, Mr. Owen Harris",male,22.0,1,0,A/5 21171,7.25,,S
# 2,1,1,"Cumings, Mrs. John Bradley (Florence Briggs Thayer)",female,38.0,1,0,PC 17599,71.2833,C85,C
# 3,1,3,"Heikkinen, Miss. Laina",female,26.0,0,0,STON/O2. 3101282,7.925,,S
# 4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May Peel)",female,35.0,1,0,113803,53.1,C123,S

# %%
dataframe = pd.read_csv('titanic_dropna.csv', index_col=0)

# %%
dataframe.head(1000)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 19                  0       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 28                  0       1
# 31                  0       1
# 34                  0       2
# 35                  0       1
# 36                  0       1
# 38                  0       3
# ...

# %%
grouped = dataframe.groupby(['Sex'])

# %%
grouped

# %%
grouped.groups
# Out:
# {'female': [2,
#   3,
#   4,
#   9,
#   10,
#   11,
#   12,
#   15,
#   16,
#   19,
#   23,
#   25,
#   26,
#   39,
#   40,
#   41,
#   42,
#   44,
#   45,
#   50,
#   53,
#   54,
#   57,
#   59,
#   67,
#   69,
#   72,
#   80,
#   85,
#   86,
#   89,
#   99,
#   101,
#   107,
#   112,
#   114,
#   115,
#   120,
#   124,
#   133,
#   134,
#   137,
#   142,
#   143,
#   148,
#   152,
#   157,
#   162,
#   168,
#   173,
#   178,
#   185,
#   191,
#   193,
#   195,
#   196,
#   200,
#   206,
#   209,
#   212,
#   216,
#   217,
#   219,
#   231,
#   234,
#   238,
#   247,
#   248,
#   252,
#   255,
#   256,
#   258,
#   259,
#   260,
#   269,
#   270,
#   273,
#   276,
#   277,
#   280,
#   290,
#   291,
#   292,
#   294,
#   298,
#   300,
#   308,
#   310,
#   311,
#   312,
#   313,
#   316,
#   317,
#   319,
#   320,
#   323,
#   324,
#   326,
#   328,
#   329,
#   330,
#   338,
#   342,
#   346,
#   347,
#   357,
#   358,
#   363,
#   367,
#   370,
#   375,
#   377,
#   381,
#   382,
# ...

# %%
grouped.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  259.000000  259.000000  259.000000  259.000000  259.000000  259.000000
# mean     0.752896    2.073359   27.745174    0.644788    0.714286   47.332433
# std      0.432163    0.843595   13.989760    0.930367    1.069045   61.517487
# min      0.000000    1.000000    0.750000    0.000000    0.000000    6.750000
# 25%      1.000000    1.000000   18.000000    0.000000    0.000000   13.000000
# 50%      1.000000    2.000000   27.000000    0.000000    0.000000   26.000000
# 75%      1.000000    3.000000   36.000000    1.000000    1.000000   56.964600
# max      1.000000    3.000000   63.000000    5.000000    6.000000  512.329200

# %%
dataframe['Sex'].max()
# Out:
# 'male'

# %%
dataframe['Survived'].max()
# Out:
# 1

# %%
dataframe_nums['Survived'].apply(lambda x: x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-8a45b88289bd> in <module>()
# ----> 1 dataframe_nums['Survived'].apply(lambda x: x*10)
#
# NameError: name 'dataframe_nums' is not defined

# %%
dataframe.np.sum['Survived']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-04144248bf71> in <module>()
# ----> 1 dataframe.np.sum['Survived']
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2244                 return self[name]
#    2245             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2246                                  (type(self).__name__, name))
#    2247
#    2248     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'np'

# %%
#What do you notice about the data? Any issues? 
#What is the overall survival rate? how to add up a column - class 4 , np.sum
#What role does gender play in surviving? what was the surival rate for women vs men - missing a step and then want to group it go to groupby documentation 
#What role does class play in surviving? missing a step but then max and min for grouped
#What role does age play in surviving? missing a step then want to go to describe 
#Given the above, do you have any guesses on what predicts survival?
#Do you have any ideas for new features we could create from the data that would help us predict if someone will survive?
