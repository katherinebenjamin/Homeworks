# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !head -5 titanic_dropna.csv
# Out:
# PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 1,0,3,"Braund, Mr. Owen Harris",male,22.0,1,0,A/5 21171,7.25,,S
# 2,1,1,"Cumings, Mrs. John Bradley (Florence Briggs Thayer)",female,38.0,1,0,PC 17599,71.2833,C85,C
# 3,1,3,"Heikkinen, Miss. Laina",female,26.0,0,0,STON/O2. 3101282,7.925,,S
# 4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May Peel)",female,35.0,1,0,113803,53.1,C123,S

# %%
dataframe = pd.read_csv('titanic_dropna.csv', index_col=0)

# %%
dataframe.head(1000)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 19                  0       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 28                  0       1
# 31                  0       1
# 34                  0       2
# 35                  0       1
# 36                  0       1
# 38                  0       3
# ...

# %%
dataframe_nums = dataframe.select_dtypes(include=[np.number])

# %%
grouped = dataframe.groupby(['Sex'])

# %%
grouped

# %%
grouped.agg(np.sum).select_dtypes(include=[np.number])
# Out:
#         Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# female       195     537   7186.00    167    185  12259.1002
# male          93    1058  13919.17    199    123  12352.7828

# %%
grouped = dataframe.groupby(['Age'])

# %%
grouped

# %%
grouped.agg(np.sum).select_dtypes(include=[np.number])
# Out:
#        Survived  Pclass  SibSp  Parch      Fare
# Age
# 0.42          1       3      0      1    8.5167
# 0.67          1       2      1      1   14.5000
# 0.75          2       6      4      2   38.5166
# 0.83          2       4      1      3   47.7500
# 0.92          1       1      1      2  151.5500
# 1.00          5      19     13     11  210.0417
# 2.00          3      26     21     13  375.3625
# 3.00          5      15     11      8  154.6917
# 4.00          7      26     16     14  295.4333
# 5.00          4      11      7      5   90.8708
# 6.00          2       8      4      4   76.7500
# 7.00          1       8      8      4   95.0625
# 8.00          2      10      8      5  113.2000
# 9.00          2      24     20     14  223.5083
# 10.00         0       6      3      4   52.0500
# 11.00         1      10     10      6  216.9625
# 12.00         1       3      1      0   11.2417
# 13.00         2       5      0      1   26.7292
# ...

# %%
grouped = dataframe.groupby(['Pclass'])

# %%
grouped

# %%
grouped.agg(np.sum).select_dtypes(include=[np.number])
# Out:
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            120  7011.42     84     76  16200.8543
# 2             83  5168.83     74     70   3714.5792
# 3             85  8924.92    208    162   4696.4495

# %%
grouped.describe()
# Out:
#                 Survived  Pclass         Age       SibSp       Parch  \
# Pclass
# 1      count  184.000000     184  184.000000  184.000000  184.000000
#        mean     0.652174       1   38.105543    0.456522    0.413043
#        std      0.477580       0   14.778904    0.634406    0.734061
#        min      0.000000       1    0.920000    0.000000    0.000000
#        25%      0.000000       1   27.000000    0.000000    0.000000
#        50%      1.000000       1   37.000000    0.000000    0.000000
#        75%      1.000000       1   49.000000    1.000000    1.000000
#        max      1.000000       1   80.000000    3.000000    4.000000
# 2      count  173.000000     173  173.000000  173.000000  173.000000
#        mean     0.479769       2   29.877630    0.427746    0.404624
#        std      0.501041       0   14.001077    0.611645    0.705775
#        min      0.000000       2    0.670000    0.000000    0.000000
# ...

# %%
dataframe['Sex'].max()
# Out:
# 'male'

# %%
dataframe['Survived'].max()
# Out:
# 1

# %%
dataframe_nums.apply(lambda x: np.sum(x), axis=0)
# Out:
# Survived      288.000
# Pclass       1595.000
# Age         21105.170
# SibSp         366.000
# Parch         308.000
# Fare        24611.883
# dtype: float64

# %%
#What do you notice about the data? Any issues? 
#I noticed a few days ago before the data was updated that there was no “Survived” column, so I was confused on how I would be able to calculate the survival rate without that information. I wonder if there is a way.
 
#What is the overall survival rate?
#Out of 891 passengers, only 288 people survived. That is a 32% survival rate.

#What role does gender play in surviving? 
#Women had a better chance at survival.  195 females survived, while only 93 men survived.

#What role does class play in surviving? 
#120 people on First Class survived, 83 people on Second Class survived and 85 people on Third Class survived. First Class had the best chance of survival, although it wasn’t as high as I would have predicted.

#What role does age play in surviving?
#101 people 23 years old and younger survived. Only 43 people 44 years and older survived. The younger people were, the better chance they had at surviving.

#Given the above, do you have any guesses on what predicts survival?
#Wealthy, young females had the best chance of survival.

#Do you have any ideas for new features we could create from the data that would help us predict if someone will survive?
#Since the life expectancy in 1912 was only 51 years old, I would like to look at the data by age bracket (0-20, 20 to 40, 40+) to better understand the role age plays in survival.
